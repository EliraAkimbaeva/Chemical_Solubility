# %% [markdown]
# <a href="https://colab.research.google.com/github/EliraAkimbaeva/ML/blob/main/prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## About the project
#
#
#
# 1.   The type of Machine Learning: Supervised
# 2.   The type(s) of model(s): Multiple Linear Regression

# %% [markdown]
# Upload the data

# %%
import pandas as pd

df = pd.read_csv('/prices.csv')
df
# Out:
#       ID  symboling                      name fueltypes aspiration  \
# 0      1          3        alfa-romero giulia       gas        std
# 1      2          3       alfa-romero stelvio       gas        std
# 2      3          1  alfa-romero Quadrifoglio       gas        std
# 3      4          2               audi 100 ls       gas        std
# 4      5          2                audi 100ls       gas        std
# ..   ...        ...                       ...       ...        ...
# 200  201         -1           volvo 145e (sw)       gas        std
# 201  202         -1               volvo 144ea       gas      turbo
# 202  203         -1               volvo 244dl       gas        std
# 203  204         -1                 volvo 246    diesel      turbo
# 204  205         -1               volvo 264gl       gas      turbo
#
#     doornumbers      carbody drivewheels enginelocation  wheelbase  ...  \
# 0           two  convertible         rwd          front       88.6  ...
# 1           two  convertible         rwd          front       88.6  ...
# 2           two    hatchback         rwd          front       94.5  ...
# 3          four        sedan         fwd          front       99.8  ...
# 4          four        sedan         4wd          front       99.4  ...
# ..          ...          ...         ...            ...        ...  ...
# 200        four        sedan         rwd          front      109.1  ...
# 201        four        sedan         rwd          front      109.1  ...
# 202        four        sedan         rwd          front      109.1  ...
# 203        four        sedan         rwd          front      109.1  ...
# 204        four        sedan         rwd          front      109.1  ...
#
#      enginesize  fuelsystem  boreratio  stroke compressionratio horsepower  \
# 0           130        mpfi       3.47    2.68              9.0        111
# 1           130        mpfi       3.47    2.68              9.0        111
# 2           152        mpfi       2.68    3.47              9.0        154
# 3           109        mpfi       3.19    3.40             10.0        102
# 4           136        mpfi       3.19    3.40              8.0        115
# ..          ...         ...        ...     ...              ...        ...
# 200         141        mpfi       3.78    3.15              9.5        114
# 201         141        mpfi       3.78    3.15              8.7        160
# 202         173        mpfi       3.58    2.87              8.8        134
# 203         145         idi       3.01    3.40             23.0        106
# 204         141        mpfi       3.78    3.15              9.5        114
#
#      peakrpm citympg  highwaympg    price
# 0       5000      21          27  13495.0
# 1       5000      21          27  16500.0
# 2       5000      19          26  16500.0
# 3       5500      24          30  13950.0
# 4       5500      18          22  17450.0
# ..       ...     ...         ...      ...
# 200     5400      23          28  16845.0
# 201     5300      19          25  19045.0
# 202     5500      18          23  21485.0
# 203     4800      26          27  22470.0
# 204     5400      19          25  22625.0
#
# [205 rows x 26 columns]

# %% [markdown]
# ## About the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   name              205 non-null    object
#  3   fueltypes         205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumbers       205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheels       205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %%
df.head()
# Out:
#    ID  symboling                      name fueltypes aspiration doornumbers  \
# 0   1          3        alfa-romero giulia       gas        std         two
# 1   2          3       alfa-romero stelvio       gas        std         two
# 2   3          1  alfa-romero Quadrifoglio       gas        std         two
# 3   4          2               audi 100 ls       gas        std        four
# 4   5          2                audi 100ls       gas        std        four
#
#        carbody drivewheels enginelocation  wheelbase  ...  enginesize  \
# 0  convertible         rwd          front       88.6  ...         130
# 1  convertible         rwd          front       88.6  ...         130
# 2    hatchback         rwd          front       94.5  ...         152
# 3        sedan         fwd          front       99.8  ...         109
# 4        sedan         4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %%
df.tail()
# Out:
#       ID  symboling             name fueltypes aspiration doornumbers carbody  \
# 200  201         -1  volvo 145e (sw)       gas        std        four   sedan
# 201  202         -1      volvo 144ea       gas      turbo        four   sedan
# 202  203         -1      volvo 244dl       gas        std        four   sedan
# 203  204         -1        volvo 246    diesel      turbo        four   sedan
# 204  205         -1      volvo 264gl       gas      turbo        four   sedan
#
#     drivewheels enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200         rwd          front      109.1  ...         141        mpfi
# 201         rwd          front      109.1  ...         141        mpfi
# 202         rwd          front      109.1  ...         173        mpfi
# 203         rwd          front      109.1  ...         145         idi
# 204         rwd          front      109.1  ...         141        mpfi
#
#      boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 200       3.78    3.15              9.5        114     5400      23
# 201       3.78    3.15              8.7        160     5300      19
# 202       3.58    2.87              8.8        134     5500      18
# 203       3.01    3.40             23.0        106     4800      26
# 204       3.78    3.15              9.5        114     5400      19
#
#      highwaympg    price
# 200          28  16845.0
# 201          25  19045.0
# 202          23  21485.0
# 203          27  22470.0
# 204          25  22625.0
#
# [5 rows x 26 columns]

# %%
df.sample(5)
# Out:
#       ID  symboling                             name fueltypes aspiration  \
# 60    61          0               mazda glc custom l       gas        std
# 74    75          1  buick regal sport coupe (turbo)       gas        std
# 121  122          1   plymouth satellite custom (sw)       gas        std
# 118  119          1                plymouth fury iii       gas        std
# 47    48          0                        jaguar xj       gas        std
#
#     doornumbers    carbody drivewheels enginelocation  wheelbase  ...  \
# 60         four      sedan         fwd          front       98.8  ...
# 74          two    hardtop         rwd          front      112.0  ...
# 121        four      sedan         fwd          front       93.7  ...
# 118         two  hatchback         fwd          front       93.7  ...
# 47         four      sedan         rwd          front      113.0  ...
#
#      enginesize  fuelsystem  boreratio  stroke compressionratio horsepower  \
# 60          122        2bbl       3.39    3.39              8.6         84
# 74          304        mpfi       3.80    3.35              8.0        184
# 121          90        2bbl       2.97    3.23              9.4         68
# 118          90        2bbl       2.97    3.23              9.4         68
# 47          258        mpfi       3.63    4.17              8.1        176
#
#      peakrpm citympg  highwaympg    price
# 60      4800      26          32   8495.0
# 74      4500      14          16  45400.0
# 121     5500      31          38   6692.0
# 118     5500      37          41   5572.0
# 47      4750      15          19  32250.0
#
# [5 rows x 26 columns]

# %%
df.loc[[0]]
# Out:
#    ID  symboling                name fueltypes aspiration doornumbers  \
# 0   1          3  alfa-romero giulia       gas        std         two
#
#        carbody drivewheels enginelocation  wheelbase  ...  enginesize  \
# 0  convertible         rwd          front       88.6  ...         130
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
#
#    highwaympg    price
# 0          27  13495.0
#
# [1 rows x 26 columns]

# %%
df.loc[[204]]
# Out:
#       ID  symboling         name fueltypes aspiration doornumbers carbody  \
# 204  205         -1  volvo 264gl       gas      turbo        four   sedan
#
#     drivewheels enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 204         rwd          front      109.1  ...         141        mpfi
#
#      boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 204       3.78    3.15              9.5        114     5400      19
#
#      highwaympg    price
# 204          25  22625.0
#
# [1 rows x 26 columns]

# %%
df.describe()
# Out:
#                ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# 25%    2145.000000   97.000000    3.150000    3.110000          8.600000
# 50%    2414.000000  120.000000    3.310000    3.290000          9.000000
# 75%    2935.000000  141.000000    3.580000    3.410000          9.400000
# max    4066.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakrpm     citympg  highwaympg         price
# count  205.000000   205.000000  205.000000  205.000000    205.000000
# mean   104.117073  5125.121951   25.219512   30.751220  13276.710571
# std     39.544167   476.985643    6.542142    6.886443   7988.852332
# min     48.000000  4150.000000   13.000000   16.000000   5118.000000
# 25%     70.000000  4800.000000   19.000000   25.000000   7788.000000
# 50%     95.000000  5200.000000   24.000000   30.000000  10295.000000
# 75%    116.000000  5500.000000   30.000000   34.000000  16503.000000
# max    288.000000  6600.000000   49.000000   54.000000  45400.000000

# %%
df.columns
# Out:
# Index(['ID', 'symboling', 'name', 'fueltypes', 'aspiration', 'doornumbers',
#        'carbody', 'drivewheels', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
df.loc()

# %%
df.iloc

# %%
df.shape
# Out:
# (205, 26)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=205, step=1)

# %%
df.nunique()
# Out:
# ID                  205
# symboling             6
# name                147
# fueltypes             2
# aspiration            2
# doornumbers           2
# carbody               5
# drivewheels           3
# enginelocation        2
# wheelbase            53
# carlength            75
# carwidth             44
# carheight            49
# curbweight          171
# enginetype            7
# cylindernumber        7
# enginesize           44
# fuelsystem            8
# boreratio            38
# stroke               37
# compressionratio     32
# horsepower           59
# peakrpm              23
# citympg              29
# highwaympg           30
# price               189
# dtype: int64

# %%
df['symboling'].value_counts()
# Out:
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: symboling, dtype: int64

# %%
df.dtypes
# Out:
# ID                    int64
# symboling             int64
# name                 object
# fueltypes            object
# aspiration           object
# doornumbers          object
# carbody              object
# drivewheels          object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
df.to_string()
# Out:
# '      ID  symboling                             name fueltypes aspiration doornumbers      carbody drivewheels enginelocation  wheelbase  carlength  carwidth  carheight  curbweight enginetype cylindernumber  enginesize fuelsystem  boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  highwaympg      price\n0      1          3               alfa-romero giulia       gas        std         two  convertible         rwd          front       88.6      168.8      64.1       48.8        2548       dohc           four         130       mpfi       3.47   2.680              9.00         111     5000       21          27  13495.000\n1      2          3              alfa-romero stelvio       gas        std         two  convertible         rwd          front       88.6      168.8      64.1       48.8        2548       dohc           four         130       mpfi       3.47   2.680              9.00         111     5000       21          27  16500.000\n2      3          1         alfa-romero Quadrifoglio       gas        std         two    hatchback         rwd          front       94.5      171.2      65.5       52.4        2823       ohcv            six         152       mpfi       2.68   3.470              9.00         154     5000       19          26  16500.000\n3      4          2                      audi 100 ls       gas        std        four        sedan         fwd          front       99.8      176.6      66.2       54.3        2337        ohc           four         109       mpfi       3.19   3.400             10.00         102     5500       24          30  13950.000\n4      5          2                       audi 100ls       gas        std        four        sedan         4wd          front       99.4      176.6      66.4       54.3        2824        ohc           five         136       mpfi       3.19   3.400              8.00         115     5500       18          22  17450.000\n5      6          2                         audi fox       gas        std         two        sedan         fwd          front       99.8      177.3      66.3       53.1        2507        ohc           five         136       mpfi       3.19   3.400              8.50         110     5500       19          25  15250.000\n6      7          1                       audi 100ls       gas        std        four        sedan         fwd          front      105.8      192.7      71.4       55.7        2844        ohc           five         136       mpfi       3.19   3.400              8.50         110     5500       19          25  17710.000\n7      8          1                        audi 5000       gas        std        four        wagon         fwd          front      105.8      192.7      71.4       55.7        2954        ohc           five         136       mpfi       3.19   3.400              8.50         110     5500       19          25  18920.000\n8      9          1                        audi 4000       gas      turbo        four        sedan         fwd          front      105.8      192.7      71.4       55.9        3086        ohc           five         131       mpfi       3.13   3.400              8.30         140     5500       17          20  23875.000\n9     10          0              audi 5000s (diesel)       gas      turbo         two    hatchback         4wd          front       99.5      178.2      67.9       52.0        3053        ohc           five         131       mpfi       3.13   3.400              7.00         160     5500       16          22  17859.167\n10    11          2                         bmw 320i       gas        std         two        sedan         rwd          front      101.2      176.8      64.8       54.3        2395        ohc           four         108       mpfi       3.50   2.800              8.80         101     5800       23          29  16430.000\n11    12          0                         bmw 320i       gas        std        four        sedan         rwd          front      101.2      176.8 ...

# %%
df.isnull()
# Out:
#         ID  symboling   name  fueltypes  aspiration  doornumbers  carbody  \
# 0    False      False  False      False       False        False    False
# 1    False      False  False      False       False        False    False
# 2    False      False  False      False       False        False    False
# 3    False      False  False      False       False        False    False
# 4    False      False  False      False       False        False    False
# ..     ...        ...    ...        ...         ...          ...      ...
# 200  False      False  False      False       False        False    False
# 201  False      False  False      False       False        False    False
# 202  False      False  False      False       False        False    False
# 203  False      False  False      False       False        False    False
# 204  False      False  False      False       False        False    False
#
#      drivewheels  enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0          False           False      False  ...       False       False
# 1          False           False      False  ...       False       False
# 2          False           False      False  ...       False       False
# 3          False           False      False  ...       False       False
# 4          False           False      False  ...       False       False
# ..           ...             ...        ...  ...         ...         ...
# 200        False           False      False  ...       False       False
# 201        False           False      False  ...       False       False
# 202        False           False      False  ...       False       False
# 203        False           False      False  ...       False       False
# 204        False           False      False  ...       False       False
#
#      boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0        False   False             False       False    False    False
# 1        False   False             False       False    False    False
# 2        False   False             False       False    False    False
# 3        False   False             False       False    False    False
# 4        False   False             False       False    False    False
# ..         ...     ...               ...         ...      ...      ...
# 200      False   False             False       False    False    False
# 201      False   False             False       False    False    False
# 202      False   False             False       False    False    False
# 203      False   False             False       False    False    False
# 204      False   False             False       False    False    False
#
#      highwaympg  price
# 0         False  False
# 1         False  False
# 2         False  False
# 3         False  False
# 4         False  False
# ..          ...    ...
# 200       False  False
# 201       False  False
# 202       False  False
# 203       False  False
# 204       False  False
#
# [205 rows x 26 columns]

# %%
df.isnull().sum()
# Out:
# ID                  0
# symboling           0
# name                0
# fueltypes           0
# aspiration          0
# doornumbers         0
# carbody             0
# drivewheels         0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.notnull()
# Out:
#        ID  symboling  name  fueltypes  aspiration  doornumbers  carbody  \
# 0    True       True  True       True        True         True     True
# 1    True       True  True       True        True         True     True
# 2    True       True  True       True        True         True     True
# 3    True       True  True       True        True         True     True
# 4    True       True  True       True        True         True     True
# ..    ...        ...   ...        ...         ...          ...      ...
# 200  True       True  True       True        True         True     True
# 201  True       True  True       True        True         True     True
# 202  True       True  True       True        True         True     True
# 203  True       True  True       True        True         True     True
# 204  True       True  True       True        True         True     True
#
#      drivewheels  enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0           True            True       True  ...        True        True
# 1           True            True       True  ...        True        True
# 2           True            True       True  ...        True        True
# 3           True            True       True  ...        True        True
# 4           True            True       True  ...        True        True
# ..           ...             ...        ...  ...         ...         ...
# 200         True            True       True  ...        True        True
# 201         True            True       True  ...        True        True
# 202         True            True       True  ...        True        True
# 203         True            True       True  ...        True        True
# 204         True            True       True  ...        True        True
#
#      boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0         True    True              True        True     True     True
# 1         True    True              True        True     True     True
# 2         True    True              True        True     True     True
# 3         True    True              True        True     True     True
# 4         True    True              True        True     True     True
# ..         ...     ...               ...         ...      ...      ...
# 200       True    True              True        True     True     True
# 201       True    True              True        True     True     True
# 202       True    True              True        True     True     True
# 203       True    True              True        True     True     True
# 204       True    True              True        True     True     True
#
#      highwaympg  price
# 0          True   True
# 1          True   True
# 2          True   True
# 3          True   True
# 4          True   True
# ..          ...    ...
# 200        True   True
# 201        True   True
# 202        True   True
# 203        True   True
# 204        True   True
#
# [205 rows x 26 columns]

# %%
df.notnull().sum()
# Out:
# ID                  205
# symboling           205
# name                205
# fueltypes           205
# aspiration          205
# doornumbers         205
# carbody             205
# drivewheels         205
# enginelocation      205
# wheelbase           205
# carlength           205
# carwidth            205
# carheight           205
# curbweight          205
# enginetype          205
# cylindernumber      205
# enginesize          205
# fuelsystem          205
# boreratio           205
# stroke              205
# compressionratio    205
# horsepower          205
# peakrpm             205
# citympg             205
# highwaympg          205
# price               205
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Length: 205, dtype: bool

# %% [markdown]
# ## Data visualization and EDA

# %%
import seaborn as sns

sns.pairplot(df)

# %%
sns.scatterplot(df)
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <ipython-input-48-6dc1c4c1753e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)
# <Axes: >

# %%
y = df["price"]
y
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %%
x = df.drop("price", axis = 1)
x
# Out:
#       ID  symboling                      name fueltypes aspiration  \
# 0      1          3        alfa-romero giulia       gas        std
# 1      2          3       alfa-romero stelvio       gas        std
# 2      3          1  alfa-romero Quadrifoglio       gas        std
# 3      4          2               audi 100 ls       gas        std
# 4      5          2                audi 100ls       gas        std
# ..   ...        ...                       ...       ...        ...
# 200  201         -1           volvo 145e (sw)       gas        std
# 201  202         -1               volvo 144ea       gas      turbo
# 202  203         -1               volvo 244dl       gas        std
# 203  204         -1                 volvo 246    diesel      turbo
# 204  205         -1               volvo 264gl       gas      turbo
#
#     doornumbers      carbody drivewheels enginelocation  wheelbase  ...  \
# 0           two  convertible         rwd          front       88.6  ...
# 1           two  convertible         rwd          front       88.6  ...
# 2           two    hatchback         rwd          front       94.5  ...
# 3          four        sedan         fwd          front       99.8  ...
# 4          four        sedan         4wd          front       99.4  ...
# ..          ...          ...         ...            ...        ...  ...
# 200        four        sedan         rwd          front      109.1  ...
# 201        four        sedan         rwd          front      109.1  ...
# 202        four        sedan         rwd          front      109.1  ...
# 203        four        sedan         rwd          front      109.1  ...
# 204        four        sedan         rwd          front      109.1  ...
#
#      cylindernumber  enginesize  fuelsystem  boreratio stroke  \
# 0              four         130        mpfi       3.47   2.68
# 1              four         130        mpfi       3.47   2.68
# 2               six         152        mpfi       2.68   3.47
# 3              four         109        mpfi       3.19   3.40
# 4              five         136        mpfi       3.19   3.40
# ..              ...         ...         ...        ...    ...
# 200            four         141        mpfi       3.78   3.15
# 201            four         141        mpfi       3.78   3.15
# 202             six         173        mpfi       3.58   2.87
# 203             six         145         idi       3.01   3.40
# 204            four         141        mpfi       3.78   3.15
#
#     compressionratio  horsepower peakrpm  citympg  highwaympg
# 0                9.0         111    5000       21          27
# 1                9.0         111    5000       21          27
# 2                9.0         154    5000       19          26
# 3               10.0         102    5500       24          30
# 4                8.0         115    5500       18          22
# ..               ...         ...     ...      ...         ...
# 200              9.5         114    5400       23          28
# 201              8.7         160    5300       19          25
# 202              8.8         134    5500       18          23
# 203             23.0         106    4800       26          27
# 204              9.5         114    5400       19          25
#
# [205 rows x 25 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=100)

# %%
X_train
# Out:
#       ID  symboling                      name fueltypes aspiration  \
# 3      4          2               audi 100 ls       gas        std
# 157  158          0       toyota corolla 1200       gas        std
# 81    82          3             mitsubishi g4       gas        std
# 32    33          1               honda civic       gas        std
# 99   100          0              nissan rogue       gas        std
# ..   ...        ...                       ...       ...        ...
# 87    88          1      mitsubishi outlander       gas      turbo
# 103  104          0               nissan otti       gas        std
# 67    68         -1  buick electra 225 custom    diesel      turbo
# 24    25          1         dodge monaco (sw)       gas        std
# 8      9          1                 audi 4000       gas      turbo
#
#     doornumbers    carbody drivewheels enginelocation  wheelbase  ...  \
# 3          four      sedan         fwd          front       99.8  ...
# 157        four  hatchback         fwd          front       95.7  ...
# 81          two  hatchback         fwd          front       96.3  ...
# 32          two  hatchback         fwd          front       93.7  ...
# 99         four  hatchback         fwd          front       97.2  ...
# ..          ...        ...         ...            ...        ...  ...
# 87         four      sedan         fwd          front       96.3  ...
# 103        four      sedan         fwd          front      100.4  ...
# 67         four      sedan         rwd          front      110.0  ...
# 24         four  hatchback         fwd          front       93.7  ...
# 8          four      sedan         fwd          front      105.8  ...
#
#      cylindernumber  enginesize  fuelsystem  boreratio stroke  \
# 3              four         109        mpfi       3.19   3.40
# 157            four          98        2bbl       3.19   3.03
# 81             four         122        2bbl       3.35   3.46
# 32             four          79        1bbl       2.91   3.07
# 99             four         120        2bbl       3.33   3.47
# ..              ...         ...         ...        ...    ...
# 87             four         110        spdi       3.17   3.46
# 103             six         181        mpfi       3.43   3.27
# 67             five         183         idi       3.58   3.64
# 24             four          90        2bbl       2.97   3.23
# 8              five         131        mpfi       3.13   3.40
#
#     compressionratio  horsepower peakrpm  citympg  highwaympg
# 3               10.0         102    5500       24          30
# 157              9.0          70    4800       30          37
# 81               8.5          88    5000       25          32
# 32              10.1          60    5500       38          42
# 99               8.5          97    5200       27          34
# ..               ...         ...     ...      ...         ...
# 87               7.5         116    5500       23          30
# 103              9.0         152    5200       19          25
# 67              21.5         123    4350       22          25
# 24               9.4          68    5500       31          38
# 8                8.3         140    5500       17          20
#
# [164 rows x 25 columns]

# %%
y_train
# Out:
# 3      13950.0
# 157     7198.0
# 81      8499.0
# 32      5399.0
# 99      8949.0
#         ...
# 87      9279.0
# 103    13499.0
# 67     25552.0
# 24      6229.0
# 8      23875.0
# Name: price, Length: 164, dtype: float64

# %%
X_test
# Out:
#       ID  symboling                             name fueltypes aspiration  \
# 160  161          0                    toyota corona       gas        std
# 186  187          2              volkswagen 411 (sw)       gas        std
# 59    60          1                        mazda 626       gas        std
# 165  166          1        toyota celica gt liftback       gas        std
# 140  141          2                        subaru dl       gas        std
# 64    65          0                        mazda 626       gas        std
# 198  199         -2                      volvo 264gl       gas      turbo
# 75    76          1                   mercury cougar       gas      turbo
# 172  173          2                  toyota cressida       gas        std
# 104  105          3                     nissan teana       gas        std
# 200  201         -1                  volvo 145e (sw)       gas        std
# 136  137          3                       saab 99gle       gas      turbo
# 111  112          0                      peugeot 504       gas        std
# 41    42          0                      honda civic       gas        std
# 73    74          0            buick century special       gas        std
# 31    32          2                 honda civic cvcc       gas        std
# 156  157          0                   toyota mark ii       gas        std
# 133  134          2                        saab 99le       gas        std
# 65    66          0                        mazda glc       gas        std
# 83    84          3                    mitsubishi g4       gas      turbo
# 195  196         -1                      volvo 144ea       gas        std
# 197  198         -1                        volvo 245       gas        std
# 126  127          3                porcshce panamera       gas        std
# 118  119          1                plymouth fury iii       gas        std
# 167  168          2           toyota corona liftback       gas        std
# 101  102          0                      nissan dayz       gas        std
# 124  125          3                  plymouth duster       gas      turbo
# 69    70          0                    buick century    diesel      turbo
# 11    12          0                         bmw 320i       gas        std
# 46    47          2                     isuzu D-Max        gas        std
# 77    78          2                mitsubishi lancer       gas        std
# 15    16          0                           bmw x4       gas        std
# 110  111          0                      peugeot 504    diesel      turbo
# 201  202         -1                      volvo 144ea       gas      turbo
# 115  116          0                      peugeot 504       gas        std
# 174  175         -1                 toyota celica gt    diesel      turbo
# 134  135          3                        saab 99le       gas        std
# 169  170          2                   toyota starlet       gas        std
# 92    93          1                     nissan latio       gas        std
# 173  174         -1                   toyota corolla       gas        std
# 74    75          1  buick regal sport coupe (turbo)       gas        std
#
#     doornumbers      carbody drivewheels enginelocation  wheelbase  ...  \
# 160        four        sedan         fwd          front       95.7  ...
# 186        four        sedan         fwd          front       97.3  ...
# 59          two    hatchback         fwd          front       98.8  ...
# 165         two        sedan         rwd          front       94.5  ...
# 140         two    hatchback         4wd          front       93.3  ...
# 64         four    hatchback         fwd          front       98.8  ...
# 198        four        sedan         rwd          front      104.3  ...
# 75          two    hatchback         rwd          front      102.7  ...
# 172         two  convertible         rwd          front       98.4  ...
# 104         two    hatchback         rwd          front       91.3  ...
# 200        four        sedan         rwd          front      109.1  ...
# 136         two    hatchback         fwd          front       99.1  ...
# 111        four        sedan         rwd          front      107.9  ...
# 41         four        sedan         fwd          front       96.5  ...
# 73         four        sedan         rwd          front      120.9  ...
# 31          two    hatchback         fwd          front       86.6  ...
# 156        four        sedan         fwd          front       95.7  ...
# 133        four        sedan         fwd          front       99.1  ...
# 65         four        sedan         rwd          front      104.9  ...
# 83          two    hatchback         fwd          front       95.9  ...
# 195        four        wagon         rwd          front      104.3  ...
# 197        four        wagon         rwd          front      104.3  ...
# 126         two      hardtop         rwd           rear       89.5  ...
# 118         two    hatchback         fwd          front       93.7  ...
# 167         two      hardtop         rwd          front       98.4  ...
# 101        four        sedan         fwd          front      100.4  ...
# 124         two    hatchback         rwd          front       95.9  ...
# 69          two      hardtop         rwd          front      106.7  ...
# 11         four        sedan         rwd          front      101.2  ...
# 46          two    hatchback         rwd          front       96.0  ...
# 77          two    hatchback         fwd          front       93.7  ...
# 15         four        sedan         rwd          front      103.5  ...
# 110        four        wagon         rwd          front      114.2  ...
# 201        four        sedan         rwd          front      109.1  ...
# 115        four        sedan         rwd          front      107.9  ...
# 174        four        sedan         fwd          front      102.4  ...
# 134         two    hatchback         fwd          front       99.1  ...
# 169         two    hatchback         rwd          front       98.4  ...
# 92         four        sedan         fwd          front       94.5  ...
# 173        four        sedan         fwd          front      102.4  ...
# 74          two      hardtop         rwd          front      112.0  ...
#
#      cylindernumber  enginesize  fuelsystem  boreratio stroke  \
# 160            four          98        2bbl       3.19   3.03
# 186            four         109        mpfi       3.19   3.40
# 59             four         122        2bbl       3.39   3.39
# 165            four          98        mpfi       3.24   3.08
# 140            four         108        2bbl       3.62   2.64
# 64             four         122        2bbl       3.39   3.39
# 198            four         130        mpfi       3.62   3.15
# 75             four         140        mpfi       3.78   3.12
# 172            four         146        mpfi       3.62   3.50
# 104             six         181        mpfi       3.43   3.27
# 200            four         141        mpfi       3.78   3.15
# 136            four         121        mpfi       3.54   3.07
# 111            four         120        mpfi       3.46   2.19
# 41             four         110        mpfi       3.15   3.58
# 73            eight         308        mpfi       3.80   3.35
# 31             four          92        1bbl       2.91   3.41
# 156            four          98        2bbl       3.19   3.03
# 133            four         121        mpfi       3.54   3.07
# 65             four         140        mpfi       3.76   3.16
# 83             four         156        spdi       3.59   3.86
# 195            four         141        mpfi       3.78   3.15
# 197            four         141        mpfi       3.78   3.15
# 126             six         194        mpfi       3.74   2.90
# 118            four          90        2bbl       2.97   3.23
# 167            four         146        mpfi       3.62   3.50
# 101             six         181        mpfi       3.43   3.27
# 124            four         156        spdi       3.59   3.86
# 69             five         183         idi       3.58   3.64
# 11             four         108        mpfi       3.50   2.80
# 46             four         119        spfi       3.43   3.23
# 77             four          92        2bbl       2.97   3.23
# 15              six         209        mpfi       3.62   3.39
# 110            four         152         idi       3.70   3.52
# 201            four         141        mpfi       3.78   3.15
# 115            four         120        mpfi       3.46   3.19
# 174            four         110         idi       3.27   3.35
# 134            four         121        mpfi       2.54   2.07
# 169            four         146        mpfi       3.62   3.50
# 92             four          97        2bbl       3.15   3.29
# 173            four         122        mpfi       3.31   3.54
# 74            eight         304        mpfi       3.80   3.35
#
#     compressionratio  horsepower peakrpm  citympg  highwaympg
# 160              9.0          70    4800       38          47
# 186              9.0          85    5250       27          34
# 59               8.6          84    4800       26          32
# 165              9.4         112    6600       26          29
# 140              8.7          73    4400       26          31
# 64               8.6          84    4800       26          32
# 198              7.5         162    5100       17          22
# 75               8.0         175    5000       19          24
# 172              9.3         116    4800       24          30
# 104              9.0         160    5200       19          25
# 200              9.5         114    5400       23          28
# 136              9.0         160    5500       19          26
# 111              8.4          95    5000       19          24
# 41               9.0         101    5800       24          28
# 73               8.0         184    4500       14          16
# 31               9.2          76    6000       31          38
# 156              9.0          70    4800       30          37
# 133              9.3         110    5250       21          28
# 65               8.0         120    5000       19          27
# 83               7.0         145    5000       19          24
# 195              9.5         114    5400       23          28
# 197              9.5         114    5400       24          28
# 126              9.5         207    5900       17          25
# 118              9.4          68    5500       37          41
# 167              9.3         116    4800       24          30
# 101              9.0         152    5200       17          22
# 124              7.0         145    5000       19          24
# 69              21.5         123    4350       22          25
# 11               8.8         101    5800       23          29
# 46               9.2          90    5000       24          29
# 77               9.4          68    5500       31          38
# 15               8.0         182    5400       16          22
# 110             21.0          95    4150       25          25
# 201              8.7         160    5300       19          25
# 115              8.4          97    5000       19          24
# 174             22.5          73    4500       30          33
# 134              9.3         110    5250       21          28
# 169              9.3         116    4800       24          30
# 92               9.4          69    5200       31          37
# 173              8.7          92    4200       29          34
# 74               8.0         184    4500       14          16
#
# [41 rows x 25 columns]

# %%
y_test
# Out:
# 160     7738.0
# 186     8495.0
# 59      8845.0
# 165     9298.0
# 140     7603.0
# 64     11245.0
# 198    18420.0
# 75     16503.0
# 172    17669.0
# 104    17199.0
# 200    16845.0
# 136    18150.0
# 111    15580.0
# 41     12945.0
# 73     40960.0
# 31      6855.0
# 156     6938.0
# 133    12170.0
# 65     18280.0
# 83     14869.0
# 195    13415.0
# 197    16515.0
# 126    32528.0
# 118     5572.0
# 167     8449.0
# 101    13499.0
# 124    12764.0
# 69     28176.0
# 11     16925.0
# 46     11048.0
# 77      6189.0
# 15     30760.0
# 110    13860.0
# 201    19045.0
# 115    16630.0
# 174    10698.0
# 134    15040.0
# 169     9989.0
# 92      6849.0
# 173     8948.0
# 74     45400.0
# Name: price, dtype: float64
